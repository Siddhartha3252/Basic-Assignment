# %%
1. How do you distinguish between shutil.copy() and shutil.copytree()?

Answer :
    
    shutil.copy() function will copy a single file where as shutil.copytree() will copy an entire folder.

# %%
2. What function is used to rename files?

Answer :
    
     os. rename() Method is used to rename files.

# %%
3. What is the difference between the delete functions in the send2trash and shutil modules?

Answer :
    
    shutil functions will permanently delete files and folders where as the send2trash functions will move a file to the recycle bin.

# %%
4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?

Answer :
    
    It is equivalent as the first argument is the filename, and the second argument is the mode to open the ZIP file either read, write or append.

# %%
5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
#Answer :

import os, shutil

def file(folder, extensions, test):
    
    folder = os.path.abspath(folder)
    test = os.path.abspath(test)
    
    print('Searching if in', folder, 'file with extensions', ', '.join(extensions))
    
    for foldername, subfolders, filenames in os.walk(folder):
        for filename in filenames:
            name, extension = os.path.splitext(filename)
            
            if extension in extensions:
                fileAbsPath = foldername + os.path.sep + filename
                print('Coping', fileAbsPath, 'to', test)
                shutil.copy(fileAbsPath, test)
                

extensions = ['.php', '.jpg']
folder = 'anyFolder'
test = 'file'
file(folder, extensions, test)
# Out:
# Searching if in C:\Users\mm\anyFolder file with extensions .php, .jpg
