# %%
1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
* 
'hello'
-87.8
- 
/ 
+	
6 

Answer :

* = expression

'hello' = Values 

-87.8 = Values

- =expression

/ = expression

+ = expression

6  Values

# %% [markdown]
# 2. What is the difference between string and variable?
#
# Answer :
#
# A string is a value representing text.
#
# A variable is a name that can refer to any value.

# %% [markdown]
# 3. Describe three different data types.
#
# Answer :
#
# Int : It is used to store numbers without a fractional component.
#
# Float : It is used to store numbers that may have a fractional component.
#
# Char : It is used to store a single letter, digit, symbol, or blank space.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?
#
# Answer :
#
# An expression is a combination of values, variables, operators.
#                                         It evaluates down to a single value.
#                                         e.g :- >>> 2 + 2
#                                                   it will evaluate down to 4.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Answer :
#
# A statements represent an action or command, e.g :- print 'hello', x = 1
#                        Where as an expression is a combination of values, variables, operators, e.g :- 5 * 5

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
#    bacon = 22
#    bacon + 1
#
#
# Answer :
#
# Here in the bacon + 1 expression does not reassign the value in bacon.it is incorrect.

# %% [markdown]
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Answer :
#
# Terms will evaluate to the string
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Answer:
#
# Variable names cannot begin with a number.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Answer :
#
# The int, float, and str functions will evaluate to the integer, float number, and string versions of the value passed to them.

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Answer :
#
# This expression will causes error because "99" is an integer, and only strings can be concatenated to other strings with the + operator.
#
# To fix this we can do this
#
# I have eaten ' + str(99) + ' burritos.'.
