# %%
1. To what does a relative path refer?

Answer :
    
    It refer to the current working directory.

# %%
2. What does an absolute path start with your operating system?

Answer :
    
    It starts with D:\.

# %%
3. What do the functions os.getcwd() and os.chdir() do?

Answer :
    
    os.getcwd() function returns the current working directory and os.chdir() function changes the current working directory.

# %%
4. What are the . and .. folders?

Answer :
    
    The . folder is the current folder, and .. is the parent folder.

# %%
5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?

Answer :
    
    spam.txt is the base name, where as C:\bacon\eggs is the dir name.

# %%
6. What are the three “mode” arguments that can be passed to the open() function?

Answer :
    
    String 'r' for read mode, 'w' for write mode, and 'a' for append mode.

# %%
7. What happens if an existing file is opened in write mode?

Answer :
    
    If existing file opened in write mode is erased and completely overwritten.

# %%
8. How do you tell the difference between read() and readlines()?

Answer :
    
     readlines() method returns a list of strings where as the read() method returns the file's entire contents as a single string value.

# %%
9. What data structure does a shelf value resemble?

Answer :
    
    It resembles a dictionary value.
