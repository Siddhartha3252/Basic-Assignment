# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
#
# Answer :
#
#     Functions reduce rewriting or duplicate code and it makes programs shorter,easier to update.
#
#
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
# Answer :
#
#     Function run when the function is called.
#
#
# 3. What statement creates a function?
#
# Answer :
#
#     The def statement creates a function.
#
#
#
# 4. What is the difference between a function and a function call?
#
# Answer :
#
#     Function consists of the def statement and the code where as function call moves the program execution into the function.
#
#
#
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Answer :
#
#     There is one global scope, and a local scope is created during function call.
#
#
# 6. What happens to variables in a local scope when the function call returns?
#
# Answer :
#
#     The local scope is vanished, and all the variables in it are lost.
#
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Answer :
#
#     It is a value that a function call evaluates to and return value can be used as an expression.
#
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Answer :
#
#      If a function does not have a return statement then its return value is None.
#
#
# 9. How do you make a function variable refer to the global variable?
#
# Answer :
#
#      we can make a function variable refer to the global variable using  Global statement.
#
#
# 10. What is the data type of None?
#
# Answer :
#
#     NoneType.
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
# Answer :
#
#     After importing that module I got this error in jupyter notebook :-
#
#    """ ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b1ea9cb2228f> in <module>
# ----> 1 import areallyourpetsnamederic
#
# ModuleNotFoundError: No module named 'areallyourpetsnamederic' """
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Answer :
#
#     It can called by spam.bacon().
#
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Answer :
#
#     We can use these code.
#
#       try:
#      your code
#     except:
#      print("Uh oh!")
#
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Answer :
#
#     Those code that could potentially cause an error will go in the try clause.
#                                Those code that executes and if an error happens will go in the except clause.

# %%
import areallyourpetsnamederic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b1ea9cb2228f> in <module>
# ----> 1 import areallyourpetsnamederic
#
# ModuleNotFoundError: No module named 'areallyourpetsnamederic'
